# %%
# !pip install -q vllm
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.9/87.9 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.9/312.9 MB 5.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 86.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.7/211.7 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 74.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.9/184.9 kB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 43.0 MB/s eta 0:00:0000:01:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 85.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 MB 44.5 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.4/358.4 kB 29.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 MB 36.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.8/755.8 kB 43.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.6/526.6 MB 3.5 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 3.8 MB/s eta 0:00:000:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 99.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 MB 21.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 90.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.2/366.2 MB 5.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.1/170.1 MB 7.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 93.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 MB 21.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 20.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.0/206.0 MB 5.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 32.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.7/197.7 MB 9.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 MB 2.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 110.5 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.1/214.1 MB 4.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 60.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 MB 32.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.9/200.9 MB 7.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.9/145.9 MB 3.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.7/767.7 kB 32.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.0/148.0 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 66.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 72.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 81.3 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 111.9 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.7/125.7 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 95.7 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 97.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 17.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.4/323.4 kB 24.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 53.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 101.6 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 109.7 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.0/516.0 kB 31.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 MB 45.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 461.2/461.2 kB 27.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.8/149.8 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 115.7 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 kB 21.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 808.1/808.1 kB 45.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.4/95.4 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 20.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 7.9 MB/s eta 0:00:000:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.7/320.7 kB 21.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 MB 21.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.3/29.3 MB 69.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 91.6 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 MB 43.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.2/201.2 kB 15.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.8/897.8 kB 47.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 112.8 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.1/78.1 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 111.9 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 MB 50.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 109.0 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.4/157.4 kB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.3/69.3 MB 28.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 927.8/927.8 kB 46.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.39.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.29.0 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# grpcio-tools 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.33.6 which is incompatible.
# ydata-profiling 4.18.4 requires numba<0.63,>=0.60, but you have numba 0.65.0 which is incompatible.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# pylibcudf-cu12 26.2.1 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 13.3.1 which is incompatible.
# numba-cuda 0.22.2 requires cuda-core<1.0.0,>=0.3.2, but you have cuda-core 1.0.1 which is incompatible.
# libcuml-cu12 26.2.0 requires cuda-toolkit[cublas,cufft,curand,cusolver,cusparse]==12.*, but you have cuda-toolkit 13.0.3.0 which is incompatible.
# rmm-cu12 26.2.0 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 13.3.1 which is incompatible.
# cuml-cu12 26.2.0 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 13.3.1 which is incompatible.
# cuml-cu12 26.2.0 requires cuda-toolkit[cublas,cufft,curand,cusolver,cusparse]==12.*, but you have cuda-toolkit 13.0.3.0 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.0 which is incompatible.
# pylibraft-cu12 26.2.0 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 13.3.1 which is incompatible.
# cuvs-cu12 26.2.0 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 13.3.1 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.33.6 which is incompatible.
# cudf-cu12 26.2.1 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 13.3.1 which is incompatible.
# cudf-cu12 26.2.1 requires cuda-toolkit[nvcc,nvrtc]==12.*, but you have cuda-toolkit 13.0.3.0 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.0 which is incompatible.
# libcuvs-cu12 26.2.0 requires cuda-toolkit[cublas,curand,cusolver,cusparse]==12.*, but you have cuda-toolkit 13.0.3.0 which is incompatible.
# libraft-cu12 26.2.0 requires cuda-toolkit[cublas,curand,cusolver,cusparse]==12.*, but you have cuda-toolkit 13.0.3.0 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.33.6 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.44.0 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.44.0 which is incompatible.
# google-adk 1.29.0 requires starlette<1.0.0,>=0.49.1, but you have starlette 1.6.0 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.44.0 which is incompatible.
# gradio 5.50.0 requires starlette<1.0,>=0.40.0, but you have starlette 1.6.0 which is incompatible.

# %%
import torch
from vllm import LLM, SamplingParams

llm = LLM(
    model="Qwen/Qwen2.5-3B-Instruct",
    dtype="half",
    gpu_memory_utilization=0.85,
    max_model_len=2048,
)
print(torch.cuda.get_device_name(0))
# Out:
# INFO 08-20 22:05:35 [api_utils.py:273] non-default args: {'dtype': 'half', 'max_model_len': 2048, 'gpu_memory_utilization': 0.85, 'disable_log_stats': True, 'model': 'Qwen/Qwen2.5-3B-Instruct'}
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/661 [00:00<?, ?B/s]
# INFO 08-20 22:05:51 [model.py:645] Resolved architecture: Qwen2ForCausalLM
# WARNING 08-20 22:05:51 [model.py:2217] Casting torch.bfloat16 to torch.float16.
# INFO 08-20 22:05:51 [model.py:1883] Using max model len 2048
# INFO 08-20 22:05:51 [scheduler.py:242] Chunked prefill is enabled with max_num_batched_tokens=8192.
# INFO 08-20 22:05:51 [kernel.py:306] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['native'], fused_add_rms_norm=['native'])
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# (EngineCore pid=225) INFO 08-20 22:05:55 [core.py:121] Initializing a V1 LLM engine (v0.27.1) with config: model='Qwen/Qwen2.5-3B-Instruct', speculative_config=None, tokenizer='Qwen/Qwen2.5-3B-Instruct', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=2048, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, decode_context_parallel_size=1, dcp_comm_backend=ag_rs, disable_custom_all_reduce=False, quantization=None, quantization_config=None, enforce_eager=False, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False, jit_monitor_mode='warn', jit_monitor_verbose=False), seed=0, served_model_name=Qwen/Qwen2.5-3B-Instruct, enable_prefix_caching=True, enable_chunked_prefill=True, pooler_config=None, compilation_config={'mode': <CompilationMode.VLLM_COMPILE: 3>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['none'], 'ir_enable_torch_wrap': True, 'splitting_ops': ['vllm::unified_attention_with_output', 'vllm::unified_mla_attention_with_output', 'vllm::mamba_mixer2', 'vllm::mamba_mixer', 'vllm::short_conv', 'vllm::linear_attention', 'vllm::qwen_gdn_attention_core', 'vllm::gdn_attention_core_xpu', 'vllm::olmo_hybrid_gdn_full_forward', 'vllm::sparse_attn_indexer', 'vllm::rocm_aiter_sparse_attn_indexer', 'vllm::deepseek_v4_attention', 'vllm::hpc_rope_norm_forward', 'vllm::unified_kv_cache_update', 'vllm::unified_mla_kv_cache_update'], 'compile_mm_encoder': False, 'cudagraph_mm_encoder': False, 'encoder_cudagraph_token_budgets': [], 'encoder_cudagraph_max_vision_items_per_batch': 0, 'encoder_cudagraph_max_frames_per_batch': None, 'compile_sizes': [], 'compile_ranges_endpoints': [8192], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.FULL_AND_PIECEWISE: (2, 1)>, 'cudagraph_num_of_warmups': 1, 'cudagraph_capture_sizes': [1, 2, 4, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256, 272, 288, 304, 320, 336, 352, 368, 384, 400, 416, 432, 448, 464, 480, 496, 512], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': False, 'fuse_act_quant': False, 'fuse_attn_quant': False, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False, 'enable_qk_norm_rope_fusion': False, 'fuse_rope_kvcache_cat_mla': False, 'fuse_act_padding': False, 'fuse_qk_norm_rope_kvcache': False}, 'max_cudagraph_capture_size': 512, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': False}, 'local_cache_dir': None, 'fast_moe_cold_start': False, 'static_all_moe_layers': []}, kernel_config=KernelConfig(ir_op_priority=IrOpPriorityConfig(rms_norm=['native'], fused_add_rms_norm=['native']), enable_flashinfer_autotune=True, enable_cutedsl_warmup=True, enable_jit_warmup=True, enable_bf16x3_router_gemm=False, moe_backend='auto', linear_backend='auto')
# (EngineCore pid=225) INFO 08-20 22:05:56 [parallel_state.py:1640] world_size=1 rank=0 local_rank=0 distributed_init_method=tcp://172.19.2.2:37119 backend=nccl
# (EngineCore pid=225) INFO 08-20 22:05:56 [parallel_state.py:1977] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A, EPLB rank N/A
# (EngineCore pid=225) INFO 08-20 22:05:56 [gpu_worker.py:385] Using V2 Model Runner
# [W820 22:05:56.877813488 socket.cpp:207] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# (EngineCore pid=225) INFO 08-20 22:05:58 [model_runner.py:308] Loading model from scratch...
# (EngineCore pid=225) ERROR 08-20 22:05:58 [fa_utils.py:273] Cannot use FA version 2 is not supported due to FA2 is only supported on devices with compute capability >= 8
# (EngineCore pid=225) INFO 08-20 22:06:00 [cuda.py:482] Using TRITON_ATTN attention backend out of potential backends: ['TRITON_ATTN', 'FLEX_ATTENTION'].
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# (EngineCore pid=225) INFO 08-20 22:06:28 [weight_utils.py:530] Time spent downloading weights for Qwen/Qwen2.5-3B-Instruct: 26.855275 seconds
# (EngineCore pid=225) INFO 08-20 22:06:28 [weight_utils.py:867] Filesystem type for checkpoints: OVERLAY. Checkpoint size: 5.75 GiB. Available RAM: 9.52 GiB.
# (EngineCore pid=225) INFO 08-20 22:06:28 [weight_utils.py:890] Auto-prefetch is disabled because the filesystem (OVERLAY) is not a recognized network FS (NFS/Lustre). If you want to force prefetching, start vLLM with --safetensors-load-strategy=prefetch.
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# (EngineCore pid=225) INFO 08-20 22:06:34 [default_loader.py:430] Loading weights took 6.04 seconds
# (EngineCore pid=225) INFO 08-20 22:06:35 [model_runner.py:329] Model loading took 5.79 GiB and 37.547930 seconds
# (EngineCore pid=225) WARNING 08-20 22:06:35 [topk_topp_sampler.py:69] FlashInfer top-p/top-k sampling unavailable: unsupported compute capability 7.5; falling back. Set VLLM_USE_FLASHINFER_SAMPLER=0 to silence.
# (EngineCore pid=225) INFO 08-20 22:06:47 [backends.py:1094] Using cache directory: /root/.cache/vllm/torch_compile_cache/c9877c3386/rank_0_0/backbone for vLLM's torch.compile
# (EngineCore pid=225) INFO 08-20 22:06:47 [backends.py:1155] Dynamo bytecode transform time: 9.72 s
# (EngineCore pid=225) [rank0]:W0820 22:06:53.328000 225 torch/_inductor/utils.py:1953] Not enough SMs to use max_autotune_gemm mode
# (EngineCore pid=225) INFO 08-20 22:06:56 [backends.py:393] Compiling a graph for compile range (1, 8192) takes 8.74 s
# (EngineCore pid=225) INFO 08-20 22:07:01 [backends.py:920] collected artifacts: 37 entries, 3 artifacts, 4644248 bytes total
# (EngineCore pid=225) INFO 08-20 22:07:01 [decorators.py:708] saved AOT compiled function to /root/.cache/vllm/torch_compile_cache/torch_aot_compile/a24b1b0500f89f97da2019258db2498f937679293920d3115d6a6c0f45905adf/rank_0_0/model
# (EngineCore pid=225) INFO 08-20 22:07:01 [monitor.py:53] torch.compile took 23.76 s in total
# (EngineCore pid=225) INFO 08-20 22:07:01 [monitor.py:81] Initial profiling/warmup run took 0.09 s
# (EngineCore pid=225) INFO 08-20 22:07:05 [gpu_worker.py:563] Available KV cache memory: 5.08 GiB
# (EngineCore pid=225) INFO 08-20 22:07:05 [kv_cache_utils.py:2235] GPU KV cache size: 148,080 tokens
# (EngineCore pid=225) INFO 08-20 22:07:05 [kv_cache_utils.py:2236] Maximum concurrency for 2,048 tokens per request: 72.30x
# Capturing CUDA graphs (PIECEWISE): 100%|██████████| 51/51 [00:09<00:00,  5.13it/s]
# Capturing CUDA graphs (FULL): 100%|██████████| 35/35 [00:02<00:00, 13.62it/s]
# (EngineCore pid=225) INFO 08-20 22:07:18 [model_runner.py:791] Graph capturing finished in 13 secs, took 0.54 GiB
# (EngineCore pid=225) INFO 08-20 22:07:18 [gpu_worker.py:789] Free memory on device (14.46/14.56 GiB) on startup. Desired GPU memory utilization is (0.85, 12.38 GiB). Actual usage is 6.69 GiB for consumed memory (weights + non-torch), 0.6 GiB for peak activation, and 0.54 GiB for CUDAGraph memory. Replace gpu_memory_utilization config with `--kv-cache-memory=4722811700` (4.4 GiB) to fit into requested memory, or `--kv-cache-memory=6958247936` (6.48 GiB) to fully utilize gpu memory. Current kv cache memory in use is 5.08 GiB.
# (EngineCore pid=225) INFO 08-20 22:07:32 [jit_monitor.py:79] Kernel JIT monitor activated; monitored JIT compilations during inference will use mode=warn.
# (EngineCore pid=225) INFO 08-20 22:07:32 [core.py:348] init engine (profile, create kv cache, warmup model) took 57.70 s (compilation: 23.76 s)
# (EngineCore pid=225) INFO 08-20 22:07:33 [kernel.py:306] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['native'], fused_add_rms_norm=['native'])
# INFO 08-20 22:07:34 [hf.py:540] Detected the chat template content format to be 'string'. You can set `--chat-template-content-format` to override this.
# Tesla T4
# (EngineCore pid=225) WARNING 08-20 22:07:35 [jit_monitor.py:135] Triton kernel JIT compilation during inference: kernel_unified_attention. This causes a latency spike; consider extending warmup to cover this shape/config.

# %%
import time, numpy as np, pandas as pd

def bench(llm, n_prompts, max_tokens=128, tag=""):
    prompts = ["Summarize the causes of the French Revolution."] * n_prompts
    sp = SamplingParams(max_tokens=max_tokens, temperature=0.0, ignore_eos=True)

    t0 = time.perf_counter()
    outs = llm.generate(prompts, sp)
    elapsed = time.perf_counter() - t0

    total_tokens = sum(len(o.outputs[0].token_ids) for o in outs)
    try:
        lat = [o.metrics.finished_time - o.metrics.arrival_time for o in outs]
        lat_mean, lat_p95 = float(np.mean(lat)), float(np.percentile(lat, 95))
    except Exception:
        lat_mean = lat_p95 = elapsed

    return {
        "tag": tag,
        "batch_size": n_prompts,
        "max_tokens": max_tokens,
        "elapsed_s": round(elapsed, 2),
        "output_tokens": total_tokens,
        "tokens_per_s": round(total_tokens / elapsed, 1),
        "requests_per_s": round(n_prompts / elapsed, 2),
        "latency_mean_s": round(lat_mean, 3),
        "latency_p95_s": round(lat_p95, 3),
        "peak_vram_gib": round(torch.cuda.max_memory_allocated() / 1024**3, 2),
    }

rows = []
for bs in [1, 2, 4, 8, 16, 32, 64]:
    torch.cuda.reset_peak_memory_stats()
    try:
        row = bench(llm, bs, tag="fp16_util0.85")
        rows.append(row)
        print(row)
    except Exception as e:
        rows.append({"tag": "fp16_util0.85", "batch_size": bs, "error": str(e)[:120]})
        print("FAILED at batch", bs, "->", str(e)[:120])

df = pd.DataFrame(rows)
df.to_csv("/kaggle/working/results.csv", index=False)
df
# Out:
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.35s/it, est. speed input: 2.30 toks/s, output: 29.41 toks/s]
# {'tag': 'fp16_util0.85', 'batch_size': 1, 'max_tokens': 128, 'elapsed_s': 4.44, 'output_tokens': 128, 'tokens_per_s': 28.8, 'requests_per_s': 0.23, 'latency_mean_s': 4.441, 'latency_p95_s': 4.441, 'peak_vram_gib': 0.0}
# Rendering prompts:   0%|          | 0/2 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [00:03<00:00,  1.82s/it, est. speed input: 5.51 toks/s, output: 70.49 toks/s]
# {'tag': 'fp16_util0.85', 'batch_size': 2, 'max_tokens': 128, 'elapsed_s': 3.65, 'output_tokens': 256, 'tokens_per_s': 70.2, 'requests_per_s': 0.55, 'latency_mean_s': 3.649, 'latency_p95_s': 3.649, 'peak_vram_gib': 0.0}
# Rendering prompts:   0%|          | 0/4 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 4/4 [00:03<00:00,  1.08it/s, est. speed input: 10.79 toks/s, output: 138.11 toks/s]
# {'tag': 'fp16_util0.85', 'batch_size': 4, 'max_tokens': 128, 'elapsed_s': 3.73, 'output_tokens': 512, 'tokens_per_s': 137.4, 'requests_per_s': 1.07, 'latency_mean_s': 3.727, 'latency_p95_s': 3.727, 'peak_vram_gib': 0.0}
# Rendering prompts:   0%|          | 0/8 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 8/8 [00:03<00:00,  2.09it/s, est. speed input: 20.87 toks/s, output: 267.13 toks/s]
# {'tag': 'fp16_util0.85', 'batch_size': 8, 'max_tokens': 128, 'elapsed_s': 3.86, 'output_tokens': 1024, 'tokens_per_s': 265.6, 'requests_per_s': 2.07, 'latency_mean_s': 3.856, 'latency_p95_s': 3.856, 'peak_vram_gib': 0.0}
# Rendering prompts:   0%|          | 0/16 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 16/16 [00:04<00:00,  3.88it/s, est. speed input: 38.84 toks/s, output: 497.12 toks/s]
# {'tag': 'fp16_util0.85', 'batch_size': 16, 'max_tokens': 128, 'elapsed_s': 4.14, 'output_tokens': 2048, 'tokens_per_s': 494.1, 'requests_per_s': 3.86, 'latency_mean_s': 4.145, 'latency_p95_s': 4.145, 'peak_vram_gib': 0.0}
# Rendering prompts:   0%|          | 0/32 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 32/32 [00:05<00:00,  6.29it/s, est. speed input: 62.94 toks/s, output: 805.61 toks/s]
# {'tag': 'fp16_util0.85', 'batch_size': 32, 'max_tokens': 128, 'elapsed_s': 5.12, 'output_tokens': 4096, 'tokens_per_s': 800.1, 'requests_per_s': 6.25, 'latency_mean_s': 5.119, 'latency_p95_s': 5.119, 'peak_vram_gib': 0.0}
# Rendering prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 64/64 [00:05<00:00, 10.91it/s, est. speed input: 109.06 toks/s, output: 1396.03 toks/s]
# {'tag': 'fp16_util0.85', 'batch_size': 64, 'max_tokens': 128, 'elapsed_s': 5.92, 'output_tokens': 8192, 'tokens_per_s': 1383.9, 'requests_per_s': 10.81, 'latency_mean_s': 5.92, 'latency_p95_s': 5.92, 'peak_vram_gib': 0.0}
#              tag  batch_size  max_tokens  elapsed_s  output_tokens  \
# 0  fp16_util0.85           1         128       4.44            128
# 1  fp16_util0.85           2         128       3.65            256
# 2  fp16_util0.85           4         128       3.73            512
# 3  fp16_util0.85           8         128       3.86           1024
# 4  fp16_util0.85          16         128       4.14           2048
# 5  fp16_util0.85          32         128       5.12           4096
# 6  fp16_util0.85          64         128       5.92           8192
#
#    tokens_per_s  requests_per_s  latency_mean_s  latency_p95_s  peak_vram_gib
# 0          28.8            0.23           4.441          4.441            0.0
# 1          70.2            0.55           3.649          3.649            0.0
# 2         137.4            1.07           3.727          3.727            0.0
# 3         265.6            2.07           3.856          3.856            0.0
# 4         494.1            3.86           4.145          4.145            0.0
# 5         800.1            6.25           5.119          5.119            0.0
# 6        1383.9           10.81           5.920          5.920            0.0

# %%
import matplotlib.pyplot as plt

ok = df[df.get("tokens_per_s").notna()]
fig, ax = plt.subplots(1, 2, figsize=(11, 4))
ax[0].plot(ok.batch_size, ok.tokens_per_s, marker="o")
ax[0].set(xlabel="batch size", ylabel="output tokens/sec", title="Throughput vs batch size")
ax[1].plot(ok.batch_size, ok.latency_mean_s, marker="o", color="crimson")
ax[1].set(xlabel="batch size", ylabel="mean latency (s)", title="Latency vs batch size")
plt.tight_layout()
plt.savefig("/kaggle/working/throughput_latency.png", dpi=150)
plt.show()
